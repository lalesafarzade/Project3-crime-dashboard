# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import ssl
import certifi
from urllib import request as req
import zipfile

import requests
import html5lib
import lxml
from splinter import Browser
import pymongo

# %%
#in case the last line of code doesn't work : uncomment this code
#ssl._create_default_https_context = ssl._create_unverified_context

# %%
#Loop through every file
for i in range(0,5):
    #Read CSV file
    temp_df = pd.read_csv(f'resources/cobra{i}.zip',compression='zip')
    #If firtst file then make it the main df
    if i == 0:
#         try:
#             temp_df['poss_time'] = temp_df['poss_time'].astype('int')
#         except:
#             pass
        df = temp_df
    #Else concat with main df
    else:
#         try:
#             temp_df['poss_time'] = temp_df['poss_time'].astype('int')
#         except:
#             pass
        df = pd.concat([df, temp_df])
        
display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4d37860edc16> in <module>
#       2 for i in range(0,5):
#       3     #Read CSV file
# ----> 4     temp_df = pd.read_csv(f'resources/cobra{i}.zip',compression='zip')
#       5     #If firtst file then make it the main df
#       6     if i == 0:
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# ~\.conda\envs\PythonData\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1111             while True:
#    1112                 try:
# -> 1113                     self.fp = io.open(file, filemode)
#    1114                 except OSError:
#    1115                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources/cobra0.zip'

# %%
#Convert all occur_time to same format

#Convert to string
df['occur_time'] = df['occur_time'].astype('str')
#Take out minutes
df['occur_time_right'] = df['occur_time'].str[-2:]
#Take out the hour and possibly the ":"
df['occur_time_left'] = df['occur_time'].str[:-2]
#Remove ":"
df['occur_time_left'] = df['occur_time_left'].str.replace(":", "")
#Add leading zeros
df['occur_time_left'] = df['occur_time_left'].apply(lambda x: x.zfill(2))
#Combine hours + ":" + minutes
df['occur_time'] = df['occur_time_left']+":"+df['occur_time_right']
#Drop columns
df = df.drop(columns = ['occur_time_left', 'occur_time_right'])

#Convert all poss_time to same format

#Split on "." and take the left half to convert float to integer
df['poss_time'] = df['poss_time'].astype('str').str.split(".", expand=True)[0]
df['poss_time_right'] = df['poss_time'].str[-2:]
df['poss_time_left'] = df['poss_time'].str[:-2]
df['poss_time_left'] = df['poss_time_left'].str.replace(":", "")
df['poss_time_left'] = df['poss_time_left'].apply(lambda x: x.zfill(2))
df['poss_time'] = df['poss_time_left']+":"+df['poss_time_right']
df = df.drop(columns = ['poss_time_left', 'poss_time_right'])

# %%
display(df)
# Out:
#         offense_id    rpt_date  occur_date occur_time   poss_date poss_time  \
# 0        203140048   2/21/2022   11/9/2020      00:32   11/9/2020     01:49
# 1        203421469   2/27/2022   12/7/2020      19:43   12/7/2020     20:26
# 2        203530136   2/21/2022  12/18/2020      01:28  12/18/2020     01:48
# 3        210121730   1/12/2022   1/12/2021      19:33   1/12/2021     19:38
# 4        210638051    2/2/2022    3/4/2021      19:50    3/4/2021     19:50
# ...            ...         ...         ...        ...         ...       ...
# 342909   193652089  12/31/2019  12/31/2019      20:30  12/31/2019     20:34
# 342910   193650336  12/31/2019  12/31/2019      04:32  12/31/2019     04:32
# 342911   193650603  12/31/2019  12/31/2019      09:20  12/31/2019     09:40
# 342912   193651760  12/31/2019  12/31/2019      18:53  12/31/2019     19:00
# 342913   193652591  12/31/2019  12/31/2019      20:45  12/31/2019     20:55
#
#                                                  location          shift  \
# 0       2111 CAMPBELLTON RD SW\nATLANTA, GA 30311\nUNI...            NaN
# 1       150 PEYTON PL SW\nATLANTA, GA 30311\nUNITED ST...            NaN
# 2       2460 MARTIN LUTHER KING JR DR SW\nATLANTA, GA ...            NaN
# 3       396 PIEDMONT AVE NE\nATLANTA, GA 30308\nUNITED...            NaN
# 4       4300 GLOBAL GATEWAY CONN\nCOLLEGE PARK, GA 303...            NaN
# ...                                                   ...            ...
# 342909                                  1385 SHARON ST NW  Morning Watch
# 342910                                    262 PHARR RD NE  Morning Watch
# 342911                                 689 CASCADE AVE SW      Day Watch
# 342912                                 763 CASCADE AVE SW  Evening Watch
# 342913                                   237 PEYTON PL SW  Evening Watch
#
#                 UC2_Literal         neighborhood        lat       long
# 0               AGG ASSAULT           Adams Park  33.706526 -84.458000
# 1       LARCENY-NON VEHICLE      Harland Terrace  33.750613 -84.473202
# 2       LARCENY-NON VEHICLE      Harland Terrace  33.752019 -84.468223
# 3               AGG ASSAULT             Downtown  33.764937 -84.382610
# 4                AUTO THEFT                  NaN  33.637951 -84.468052
# ...                     ...                  ...        ...        ...
# 342909          AGG ASSAULT         Hunter Hills  33.754860 -84.432870
# 342910          AGG ASSAULT     Buckhead Village  33.837320 -84.378600
# 342911          AGG ASSAULT             Westview  33.736360 -84.436800
# 342912          AGG ASSAULT             Westview  33.734830 -84.437500
# 342913          AGG ASSAULT  Cascade Avenue/Road  33.725180 -84.450130
#
# [391481 rows x 12 columns]

# %%
#Convert data to dictionary for Mongo DB

df.reset_index(inplace=True)

data_dict = df.to_dict('records')

# %%
conn = 'mongodb://localhost:27017'

client = pymongo.MongoClient(conn)

db = client.crime_db

collection = db.crime_info

collection.delete_many({})

collection.insert_many(data_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a942279338f> in <module>
#       1 conn = 'mongodb://localhost:27017'
#       2
# ----> 3 client = pymongo.MongoClient(conn)
#       4
#       5 db = client.crime_db
#
# NameError: name 'pymongo' is not defined

# %%
username = 'user'
password = 'pythonclass'

myconnection = f'mongodb+srv://{username}:{password}@cluster0.n5itv.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'

myclient = pymongo.MongoClient(myconnection)

db = myclient.crime_db

collection = db.crime_info

collection.delete_many({})

collection.insert_many(data_dict)

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'local']
