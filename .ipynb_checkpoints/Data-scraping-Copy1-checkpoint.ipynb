# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import ssl
import certifi
from urllib import request as req
import zipfile

import requests
import html5lib
import lxml
from splinter import Browser
import pymongo

# %%
#in case the last line of code doesn't work : uncomment this code
#ssl._create_default_https_context = ssl._create_unverified_context

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/99.0.4844.51/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\16789\.wdm\drivers\chromedriver\win32\99.0.4844.51]

# %%
url = 'https://www.atlantapd.org/i-want-to/crime-data-downloads'
browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
quotes = soup.find_all('div', id='widget_362_0_197')

# %%
lis=quotes[0].find_all('li')
Download_url=[]
for li in lis:
    link=li.find("a")
    href=link["href"]
    Download_url.append("https://www.atlantapd.org"+href)

# %%
Download_url
# Out:
# ['https://www.atlantapd.org/home/showpublisheddocument/4730/637843168152670000',
#  'https://www.atlantapd.org/home/showpublisheddocument/4576/637770569750770000',
#  'https://www.atlantapd.org/home/showpublisheddocument/3705/637460445573930000',
#  'https://www.atlantapd.org/home/showpublisheddocument/3587/637418951324270000',
#  'https://www.atlantapd.org/home/showpublisheddocument/3051/637141450644130000']

# %%
for i in range(len(Download_url)):
    try:
        local_file = f'Resources/cobra{i}.zip'
        req.urlretrieve(Download_url[i], local_file)
    except:
        print("something is wrong :( ")

# %%
import zipfile
import pandas as pd
 

df = pd.read_csv('Resources/cobra0.zip',compression='zip')
 

df.head()
# Out:
#    offense_id   rpt_date  occur_date occur_day  occur_day_num occur_time  \
# 0   203140048  2/21/2022   11/9/2020    Monday            2.0      00:32
# 1   203421469  2/27/2022   12/7/2020    Monday            2.0      19:43
# 2   203530136  2/21/2022  12/18/2020    Friday            6.0      01:28
# 3   210121730  1/12/2022   1/12/2021   Tuesday            3.0      19:33
# 4   210638051   2/2/2022    3/4/2021  Thursday            5.0      19:50
#
#     poss_date poss_time  beat  zone  \
# 0   11/9/2020     01:49   409     4
# 1   12/7/2020     20:26   405     4
# 2  12/18/2020     01:48   405     4
# 3   1/12/2021     19:38   509     5
# 4    3/4/2021     19:50   707     7
#
#                                             location ibr_code  \
# 0  2111 CAMPBELLTON RD SW\nATLANTA, GA 30311\nUNI...      13A
# 1  150 PEYTON PL SW\nATLANTA, GA 30311\nUNITED ST...      23B
# 2  2460 MARTIN LUTHER KING JR DR SW\nATLANTA, GA ...      23H
# ...

# %%
import zipfile
import pandas as pd
 

df = pd.read_csv('Resources/cobra1.zip',compression='zip')
 

df.head()
# Out:
#    offense_id   rpt_date occur_date  occur_day  occur_day_num occur_time  \
# 0    21140096  5/20/2021  5/19/2021  Wednesday            4.0      15:20
# 1    21791668  6/28/2021  6/27/2021     Sunday            1.0      21:17
# 2   200041082   1/5/2021   1/4/2021     Monday            2.0      16:00
# 3   202611428  9/18/2021  9/18/2021   Saturday            7.0      18:04
# 4   202771329  8/19/2021  10/3/2020   Saturday            7.0      16:29
#
#    poss_date poss_time  beat  zone  \
# 0  5/19/2021     15:25   103     1
# 1  6/28/2021     20:00   102     1
# 2   1/4/2021     17:00   605     6
# 3  9/18/2021     18:15   112     1
# 4  10/3/2020     16:29   109     1
#
#                                             location ibr_code  \
# 0  1720 MARIETTA BLVD NW\nATLANTA, GA 30318\nUNIT...      23F
# 1  870 MAYSON TURNER RD NW\nATLANTA, GA 30314\nUN...      23H
# 2  275 MEMORIAL DR SE\nATLANTA, GEORGIA 30312\nUN...      23C
# ...

# %%
import zipfile
import pandas as pd
 

df = pd.read_csv('Resources/cobra2.zip',compression='zip')
 

df.head()
# Out:
#    offense_id    rpt_date  occur_date occur_time   poss_date poss_time beat  \
# 0   203341346  12/31/2020  11/29/2020      19:21  11/29/2020     23:50  405
# 1   203631200  12/31/2020  12/28/2020      17:21  12/28/2020     17:45  302
# 2   203631285  12/31/2020  12/24/2020      14:00  12/24/2020     18:26  603
# 3   203651634  12/31/2020  12/30/2020      20:15  12/30/2020     22:25  211
# 4   203660108  12/31/2020  12/31/2020       1:15  12/31/2020      1:15  306
#
#    apt_office_prefix  apt_office_num              location  MinOfucr  \
# 0                NaN             NaN  3050 M.L.K. JR DR SW       NaN
# 1                NaN             NaN        1186 IRA ST SW       NaN
# 2                NaN             NaN   501 BOULEVARD PL NE       NaN
# 3                NaN             NaN   3101 PIEDMONT RD NE       NaN
# 4                NaN             NaN     1974 SYLVAN RD SW       NaN
#
#    dispo_code  Shift  loc_type           UC2_Literal ibr_code  \
# ...

# %%
import zipfile
import pandas as pd
 

df = pd.read_csv('Resources/cobra3.zip',compression='zip')
 

df.head()
# Out:
#    offense_id   rpt_date occur_date occur_time  poss_date poss_time   beat  \
# 0   200021209   1/2/2020   1/2/2020      15:21   1/2/2020     15:35  511.0
# 1   200061707   1/6/2020   1/6/2020       0:00   1/6/2020     18:25  109.0
# 2   200100013  1/10/2020   1/9/2020      23:45  1/10/2020      0:00  110.0
# 3   200151818  1/16/2020  1/15/2020      17:15  1/15/2020     17:40  401.0
# 4   200180440  1/18/2020  1/18/2020       3:31  1/18/2020      3:31  206.0
#
#   apartment_office_prefix apartment_number                location  \
# 0                     NaN              NaN          12 BROAD ST SW
# 1                     NaN              NaN       785 PEYTON AVE NW
# 2                     NaN              NaN       1977 JONES AVE NW
# 3                     NaN              NaN  549 JOSEPH LOWERY BLVD
# 4                     NaN              NaN          28 IRBY AVE NW
#
#            watch  location_type UC2_Literal  UCR_Number       neighborhood  \
# ...

# %%
import zipfile
import pandas as pd
 

df = pd.read_csv('Resources/cobra4.zip',compression='zip')
 

df.head()
# Out:
# C:\Users\16789\.conda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (3,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Report Number Report Date  Occur Date Occur Time Possible Date  \
# 0       90010930  2009-01-01  2009-01-01       1145    2009-01-01
# 1       90011083  2009-01-01  2009-01-01       1330    2009-01-01
# 2       90011208  2009-01-01  2009-01-01       1500    2009-01-01
# 3       90011218  2009-01-01  2009-01-01       1450    2009-01-01
# 4       90011289  2009-01-01  2009-01-01       1600    2009-01-01
#
#    Possible Time   Beat Apartment Office Prefix Apartment Number  \
# 0         1148.0  411.0                     NaN              NaN
# 1         1330.0  511.0                     NaN              NaN
# 2         1520.0  407.0                     NaN              NaN
# ...

# %%
# conn = 'mongodb://localhost:27017'

# client = pymongo.MongoClient(conn)

# db = client.crime_db

# data = list(db.crime_info.find())[0]

# data

# %%
#Loop through every file
for i in range(0,5):
    #Read CSV file
    temp_df = pd.read_csv(f'Resources/cobra{i}.zip',compression='zip')
    #If firtst file then make it the main df
    if i == 0:
        df = temp_df
    #Else concat with main df
    else:
        df = pd.concat([df, temp_df])
        
display(df)
# Out:
# C:\Users\16789\.conda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         offense_id    rpt_date  occur_date occur_time   poss_date poss_time  \
# 0        203140048   2/21/2022   11/9/2020       0:32   11/9/2020      1:49
# 1        203421469   2/27/2022   12/7/2020      19:43   12/7/2020     20:26
# 2        203530136   2/21/2022  12/18/2020       1:28  12/18/2020      1:48
# 3        210121730   1/12/2022   1/12/2021      19:33   1/12/2021     19:38
# 4        210638051    2/2/2022    3/4/2021      19:50    3/4/2021     19:50
# ...            ...         ...         ...        ...         ...       ...
# 342909   193652089  12/31/2019  12/31/2019       2030  12/31/2019      2034
# 342910   193650336  12/31/2019  12/31/2019        432  12/31/2019       432
# ...

# %%
conn = 'mongodb://localhost:27017'

client = pymongo.MongoClient(conn)

db = client.crime_db

collection = db.crime_info

# %%
df.reset_index(inplace=True)

# %%
data_dict = df.to_dict('records')

# %%
collection.insert_many(data_dict)
